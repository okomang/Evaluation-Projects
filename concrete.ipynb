# %%
import pandas as pd
import numpy as np

# %%
c=pd.read_csv('concrete.csv')

# %%
c
# Out:
#       Cement  Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age  \
# 0      540.0    0.0      0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0      0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5      0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5      0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4      0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...      ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0     90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0    115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4    108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7      0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5     78.3  200.6               8.6   864.5  761.5   28
#
#         CMS
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# ...

# %%
#In this dataset CMS(Concrete Compressive strength) is our output variable while rest are indpendent variables

# %%
c.isnull().sum()
# Out:
# Cement              0
# Blast               0
# Fly Ash             0
# Water               0
# Superplasticizer    0
# CA                  0
# FA                  0
# Age                 0
# CMS                 0
# dtype: int64

# %%
import seaborn as sb

# %%
sb.heatmap(c.isnull())

# %%
#There are no null values

# %%
import matplotlib.pyplot as plt

# %%
c.corr()
# Out:
#                     Cement     Blast   Fly Ash     Water  Superplasticizer  \
# Cement            1.000000 -0.275216 -0.397467 -0.081587          0.092386
# Blast            -0.275216  1.000000 -0.323580  0.107252          0.043270
# Fly Ash          -0.397467 -0.323580  1.000000 -0.256984          0.377503
# Water            -0.081587  0.107252 -0.256984  1.000000         -0.657533
# Superplasticizer  0.092386  0.043270  0.377503 -0.657533          1.000000
# CA               -0.109349 -0.283999 -0.009961 -0.182294         -0.265999
# FA               -0.222718 -0.281603  0.079108 -0.450661          0.222691
# Age               0.081946 -0.044246 -0.154371  0.277618         -0.192700
# CMS               0.497832  0.134829 -0.105755 -0.289633          0.366079
#
#                         CA        FA       Age       CMS
# Cement           -0.109349 -0.222718  0.081946  0.497832
# Blast            -0.283999 -0.281603 -0.044246  0.134829
# ...

# %%
sb.heatmap(c.corr())

# %%
#Superplasticizer and water are negatively co related with each other
#Cement superplasticizer and age are postievely co related with CMS

# %% [markdown]
# # GRAPHICAL ANALYSIS

# %%
c
# Out:
#       Cement  Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age  \
# 0      540.0    0.0      0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0      0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5      0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5      0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4      0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...      ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0     90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0    115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4    108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7      0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5     78.3  200.6               8.6   864.5  761.5   28
#
#         CMS
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# ...

# %%
c.columns
# Out:
# Index(['Cement', 'Blast', 'Fly Ash', 'Water', 'Superplasticizer', 'CA', 'FA',
#        'Age', 'CMS'],
#       dtype='object')

# %%
sb.countplot(c['Age'])

# %%
#The maximum age is 365 years and the most frequent age is 28 years

# %%
c['Age'].value_counts()
# Out:
# 28     425
# 3      134
# 7      126
# 56      91
# 14      62
# 90      54
# 100     52
# 180     26
# 91      22
# 365     14
# 270     13
# 360      6
# 120      3
# 1        2
# Name: Age, dtype: int64

# %%
#The least age is 1 year

# %%
sb.distplot(c['CMS'])

# %%
#CMS is almost normalized and the mean would be at about 40 CMS has a wide range between 0-90

# %%
c['CMS'].value_counts()
# Out:
# 33.40    6
# 71.30    4
# 41.05    4
# 31.35    4
# 23.52    4
#         ..
# 38.33    1
# 10.73    1
# 30.45    1
# 39.84    1
# 36.25    1
# Name: CMS, Length: 845, dtype: int64

# %%
sb.scatterplot(x=c['Water'],y=c['Cement'],data=c)

# %%
#The water in cement is usually between 170-200

# %%
sb.scatterplot(x=c['Age'],y=c['CMS'],data=c)

# %%
#CMS is highly dependent on Age and the morwe the Age the less the CMS,more CMS is shown between age of 0-100

# %%
sb.lineplot(x=c['Superplasticizer'],y=c['CMS'],data=c)

# %%
sb.scatterplot(x=c['Superplasticizer'],y=c['CMS'],data=c)

# %%
#Most of the Superplasticizer value ranges from 5-10 in common practice.

# %%
sb.catplot(x='Fly Ash',y='CMS',data=c)

# %%
#FlyAsh is not highly effecting CMS

# %%
sb.pairplot(c)

# %% [markdown]
# # STATISTICAL ANALYSIS

# %%
c.describe()
# Out:
#             Cement        Blast      Fly Ash        Water  Superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#                 CA           FA          Age          CMS
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# ...

# %%
#The maximum cement is 540,and avaerage cement preferred is 281.16
#The average CMS preferred in 35.81 in the industry.
#The high gap between 75% and max in Blast and Superplasticizer and age shows there are outliers in data.

# %% [markdown]
# # CHECKING OUTLIERS

# %%
import scipy
from scipy import stats
from scipy.stats import zscore

# %%
c['Blast'].plot.box()

# %%
c['Superplasticizer'].plot.box()

# %%
c.plot(kind='box',layout=(4,4),subplots=True,figsize=(10,10))
# Out:
# Cement                  AxesSubplot(0.125,0.71587;0.168478x0.16413)
# Blast                AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# Fly Ash              AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# Water                AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# Superplasticizer       AxesSubplot(0.125,0.518913;0.168478x0.16413)
# CA                  AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# FA                  AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# Age                 AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# CMS                    AxesSubplot(0.125,0.321957;0.168478x0.16413)
# dtype: object

# %%
z=np.abs(zscore(c))

# %%
print(np.where (z>3))
# Out:
# (array([  2,   3,   4,   6,  12,  17,  24,  25,  26,  30,  31,  33,  34,
#         35,  41,  42,  56,  60,  61,  63,  65,  66,  76,  79,  99, 102,
#        122, 125, 145, 148, 168, 171, 553, 559, 571, 584, 604, 610, 616,
#        620, 622, 756, 769, 792, 798, 814, 820, 873, 936], dtype=int64), array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 1, 1, 1, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 3, 3], dtype=int64))

# %%
c_new=c[(z<3).all (axis=1)]

# %%
print(c.shape)
print(c_new.shape)
# Out:
# (1030, 9)
# (981, 9)

# %%
c_new.plot(kind='box',layout=(4,4),subplots=True,figsize=(10,10))
# Out:
# Cement                  AxesSubplot(0.125,0.71587;0.168478x0.16413)
# Blast                AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# Fly Ash              AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# Water                AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# Superplasticizer       AxesSubplot(0.125,0.518913;0.168478x0.16413)
# CA                  AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# FA                  AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# Age                 AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# CMS                    AxesSubplot(0.125,0.321957;0.168478x0.16413)
# dtype: object

# %% [markdown]
# # CHECKING SKEWNESS

# %%
c_new.skew()
# Out:
# Cement              0.508557
# Blast               0.747827
# Fly Ash             0.461726
# Water              -0.017778
# Superplasticizer    0.416828
# CA                 -0.087932
# FA                 -0.226214
# Age                 1.940232
# CMS                 0.463962
# dtype: float64

# %%
c_new.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8F9EB7640>,
# ...
#       dtype=object)

# %%
import warnings
warnings.filterwarnings('ignore')

for col in c_new.columns:
    if c_new.skew().loc[col]>0.55:
        c_new[col]=np.log1p(c_new[col])

# %%
c_new.skew()
# Out:
# Cement              0.508557
# Blast              -0.021576
# Fly Ash             0.461726
# Water              -0.017778
# Superplasticizer    0.416828
# CA                 -0.087932
# FA                 -0.226214
# Age                -0.269706
# CMS                 0.463962
# dtype: float64

# %%
c_new.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8F9C75BE0>,
# ...
#       dtype=object)

# %%
c_new
# Out:
#       Cement     Blast  Fly Ash  Water  Superplasticizer      CA     FA  \
# 0      540.0  0.000000      0.0  162.0               2.5  1040.0  676.0
# 1      540.0  0.000000      0.0  162.0               2.5  1055.0  676.0
# 5      266.0  4.744932      0.0  228.0               0.0   932.0  670.0
# 7      380.0  4.564348      0.0  228.0               0.0   932.0  594.0
# 8      266.0  4.744932      0.0  228.0               0.0   932.0  670.0
# ...      ...       ...      ...    ...               ...     ...    ...
# 1025   276.4  4.762174     90.3  179.6               8.9   870.1  768.3
# 1026   322.2  0.000000    115.6  196.0              10.4   817.9  813.4
# 1027   148.5  4.944495    108.6  192.7               6.1   892.4  780.0
# 1028   159.1  5.234845      0.0  175.6              11.3   989.6  788.9
# 1029   260.9  4.620059     78.3  200.6               8.6   864.5  761.5
#
#            Age    CMS
# 0     3.367296  79.99
# 1     3.367296  61.89
# 5     4.510860  47.03
# ...

# %%
#Let us Normalize the data using Standard Scaler so it is finally ready to fit for a model

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
s=StandardScaler()
C=pd.DataFrame(s.fit_transform(c_new),columns=c_new.columns)

# %%
C
# Out:
#        Cement     Blast   Fly Ash     Water  Superplasticizer        CA  \
# 0    2.560014 -1.053679 -0.881120 -0.931973         -0.673726  0.839761
# 1    2.560014 -1.053679 -0.881120 -0.931973         -0.673726  1.032749
# 2   -0.112045  0.916157 -0.881120  2.346817         -1.129625 -0.549747
# 3    0.999687  0.841188 -0.881120  2.346817         -1.129625 -0.549747
# 4   -0.112045  0.916157 -0.881120  2.346817         -1.129625 -0.549747
# ..        ...       ...       ...       ...               ...       ...
# 976 -0.010624  0.923315  0.520915 -0.057629          0.493375 -1.346141
# 977  0.436020 -1.053679  0.913734  0.757100          0.766914 -2.017736
# 978 -1.257910  0.999005  0.805049  0.593161         -0.017232 -1.059233
# 979 -1.154538  1.119542 -0.881120 -0.256344          0.931037  0.191324
# 980 -0.161780  0.864316  0.334598  0.985622          0.438667 -1.418189
#
#            FA       Age       CMS
# 0   -1.288508  0.201840  2.672454
# ...

# %% [markdown]
# # SCALING DATA INTO X AND Y TO FIT IN MACHINE LEARNING MODELS

# %%
x=C.iloc[ : , :-1]
y=C.iloc[ : ,-1]

# %%
x
# Out:
#        Cement     Blast   Fly Ash     Water  Superplasticizer        CA  \
# 0    2.560014 -1.053679 -0.881120 -0.931973         -0.673726  0.839761
# 1    2.560014 -1.053679 -0.881120 -0.931973         -0.673726  1.032749
# 2   -0.112045  0.916157 -0.881120  2.346817         -1.129625 -0.549747
# 3    0.999687  0.841188 -0.881120  2.346817         -1.129625 -0.549747
# 4   -0.112045  0.916157 -0.881120  2.346817         -1.129625 -0.549747
# ..        ...       ...       ...       ...               ...       ...
# 976 -0.010624  0.923315  0.520915 -0.057629          0.493375 -1.346141
# 977  0.436020 -1.053679  0.913734  0.757100          0.766914 -2.017736
# 978 -1.257910  0.999005  0.805049  0.593161         -0.017232 -1.059233
# 979 -1.154538  1.119542 -0.881120 -0.256344          0.931037  0.191324
# 980 -0.161780  0.864316  0.334598  0.985622          0.438667 -1.418189
#
#            FA       Age
# 0   -1.288508  0.201840
# 1   -1.288508  0.201840
# 2   -1.365815  1.316915
# ...

# %%
y
# Out:
# 0      2.672454
# 1      1.590217
# 2      0.701707
# 3      0.069106
# 4      0.631152
#          ...
# 976    0.537278
# 977   -0.245998
# 978   -0.693243
# 979   -0.150928
# 980   -0.173051
# Name: CMS, Length: 981, dtype: float64

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
def max_r2(reg,x,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=.20)
        reg.fit(x_train,y_train)
        pred=reg.predict(x_test)
        r2_scr=r2_score(pred,y_test)
        print('R2 Score is',r2_scr,'at Random State',r_state)
        
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    
    print('\n')
    print('Max R2 Score is',max_r_score, 'at random state',final_r_state)

# %%
lr=LinearRegression()
r_state=max_r2(lr,x,y)
# Out:
# R2 Score is 0.7592419138805921 at Random State 42
# R2 Score is 0.7800277652882529 at Random State 43
# R2 Score is 0.7517799452649665 at Random State 44
# R2 Score is 0.7712544190257887 at Random State 45
# R2 Score is 0.7508577565601028 at Random State 46
# R2 Score is 0.7610433921416666 at Random State 47
# R2 Score is 0.761312121149871 at Random State 48
# R2 Score is 0.7139726562343085 at Random State 49
# R2 Score is 0.7499564813391714 at Random State 50
# R2 Score is 0.7772461510229205 at Random State 51
# R2 Score is 0.7361170958614499 at Random State 52
# R2 Score is 0.7952931081973509 at Random State 53
# R2 Score is 0.7549439005510442 at Random State 54
# R2 Score is 0.7013925043200211 at Random State 55
# R2 Score is 0.7957590092044037 at Random State 56
# R2 Score is 0.7608877482241938 at Random State 57
# R2 Score is 0.7302778722312061 at Random State 58
# R2 Score is 0.7387103576595082 at Random State 59
# R2 Score is 0.7382806643834191 at Random State 60
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn import svm
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=100,test_size=0.20)

# %%
knr=KNeighborsRegressor()
parameters={ 'n_neighbors' : range(0,15)}
g=GridSearchCV(knr,parameters,cv=10)
g.fit(x_train,y_train)
g.best_params_
# Out:
# {'n_neighbors': 2}

# %%
svr=SVR()
parameters={'kernel' : ['poly','rbf','linear']}
g=GridSearchCV(svr,parameters,cv=10)
g.fit(x_train,y_train)
g.best_params_
# Out:
# {'kernel': 'rbf'}

# %%
knr=KNeighborsRegressor(n_neighbors=2)
r_state=max_r2(knr,x,y)
# Out:
# R2 Score is 0.7806617689379587 at Random State 42
# R2 Score is 0.8394215998928332 at Random State 43
# R2 Score is 0.849297331627571 at Random State 44
# R2 Score is 0.8294237721761861 at Random State 45
# R2 Score is 0.8507102912864157 at Random State 46
# R2 Score is 0.8160604879224098 at Random State 47
# R2 Score is 0.8833187650246671 at Random State 48
# R2 Score is 0.8860914568848978 at Random State 49
# R2 Score is 0.8735449122110344 at Random State 50
# R2 Score is 0.8853484825470799 at Random State 51
# R2 Score is 0.8763161158834455 at Random State 52
# R2 Score is 0.8491655883378625 at Random State 53
# R2 Score is 0.8075308775051432 at Random State 54
# R2 Score is 0.7483375362485947 at Random State 55
# R2 Score is 0.8818789636943994 at Random State 56
# R2 Score is 0.8698368031709146 at Random State 57
# R2 Score is 0.7835944568403087 at Random State 58
# R2 Score is 0.854198300246067 at Random State 59
# R2 Score is 0.8474760109350313 at Random State 60
# ...

# %%
svr=SVR(kernel='rbf')
r_state=max_r2(svr,x,y)
# Out:
# R2 Score is 0.8313912820004556 at Random State 42
# R2 Score is 0.8819648115054459 at Random State 43
# R2 Score is 0.8682594515281251 at Random State 44
# R2 Score is 0.8630065363970528 at Random State 45
# R2 Score is 0.8857651315910878 at Random State 46
# R2 Score is 0.8569128989973791 at Random State 47
# R2 Score is 0.8894455020264251 at Random State 48
# R2 Score is 0.8805248386455782 at Random State 49
# R2 Score is 0.8952246866841685 at Random State 50
# R2 Score is 0.9107008576743956 at Random State 51
# R2 Score is 0.8716148866077612 at Random State 52
# R2 Score is 0.889757898598724 at Random State 53
# R2 Score is 0.8570023292795544 at Random State 54
# R2 Score is 0.8459064891538228 at Random State 55
# R2 Score is 0.8983405774409899 at Random State 56
# R2 Score is 0.8795345599766089 at Random State 57
# R2 Score is 0.8491173251169728 at Random State 58
# R2 Score is 0.8856201792480082 at Random State 59
# R2 Score is 0.8574907129640518 at Random State 60
# ...

# %%
dt=DecisionTreeRegressor()
r_state=max_r2(dt,x,y)
# Out:
# R2 Score is 0.7493888379442311 at Random State 42
# R2 Score is 0.841677941835413 at Random State 43
# R2 Score is 0.8641138401479667 at Random State 44
# R2 Score is 0.7528310513436131 at Random State 45
# R2 Score is 0.8411686825673415 at Random State 46
# R2 Score is 0.8255631985207422 at Random State 47
# R2 Score is 0.7104893362901714 at Random State 48
# R2 Score is 0.8002001439310148 at Random State 49
# R2 Score is 0.8582646789294893 at Random State 50
# R2 Score is 0.8358555737973399 at Random State 51
# R2 Score is 0.8155589508929443 at Random State 52
# R2 Score is 0.8626957808927646 at Random State 53
# R2 Score is 0.8414621831662616 at Random State 54
# R2 Score is 0.7915147313409813 at Random State 55
# R2 Score is 0.8730955198730356 at Random State 56
# R2 Score is 0.8272128456996326 at Random State 57
# R2 Score is 0.8071671378612837 at Random State 58
# R2 Score is 0.855950266837843 at Random State 59
# R2 Score is 0.7734751865785611 at Random State 60
# ...

# %% [markdown]
# Using Regularization Model Lasso

# %%
from sklearn.linear_model import Lasso
l=Lasso()
parameters={ 'alpha' : [0.0001,0.001,0.01,1]}
g=GridSearchCV(l,parameters,cv=10)
g.fit(x_train,y_train)
g.best_params_
# Out:
# {'alpha': 0.0001}

# %%
l=Lasso(alpha=0.0001)
r_state=max_r2(l,x,y)
# Out:
# R2 Score is 0.7591509273266248 at Random State 42
# R2 Score is 0.7798988470001286 at Random State 43
# R2 Score is 0.7516361482287088 at Random State 44
# R2 Score is 0.7710939656996028 at Random State 45
# R2 Score is 0.7507705505868361 at Random State 46
# R2 Score is 0.7609377770574997 at Random State 47
# R2 Score is 0.7611937795718285 at Random State 48
# R2 Score is 0.7138357768214034 at Random State 49
# R2 Score is 0.7498380027391096 at Random State 50
# R2 Score is 0.7771433065143041 at Random State 51
# R2 Score is 0.7359588353178255 at Random State 52
# R2 Score is 0.7951729769070551 at Random State 53
# R2 Score is 0.7548165147830352 at Random State 54
# R2 Score is 0.7012303150036981 at Random State 55
# R2 Score is 0.7956049405299521 at Random State 56
# R2 Score is 0.7608083197544094 at Random State 57
# R2 Score is 0.7301940351375986 at Random State 58
# R2 Score is 0.73863876948587 at Random State 59
# R2 Score is 0.7380799461595656 at Random State 60
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
r=RandomForestRegressor()
parameters={'n_estimators' : range(0,21)}
g=GridSearchCV(r,parameters,cv=10)
g.fit(x_train,y_train)
g.best_params_
# Out:
# {'n_estimators': 17}

# %%
r=RandomForestRegressor(n_estimators=18)
r_state=max_r2(r,x,y)
# Out:
# R2 Score is 0.8237979865471017 at Random State 42
# R2 Score is 0.881577719800251 at Random State 43
# R2 Score is 0.8730995101962268 at Random State 44
# R2 Score is 0.8633637125289575 at Random State 45
# R2 Score is 0.8951416863205431 at Random State 46
# R2 Score is 0.8751896663001291 at Random State 47
# R2 Score is 0.899553903132093 at Random State 48
# R2 Score is 0.8893488461403296 at Random State 49
# R2 Score is 0.9162051775081459 at Random State 50
# R2 Score is 0.8936904168284086 at Random State 51
# R2 Score is 0.880441696841924 at Random State 52
# R2 Score is 0.910155227609605 at Random State 53
# R2 Score is 0.87426575208971 at Random State 54
# R2 Score is 0.846572775401164 at Random State 55
# R2 Score is 0.9200184868104546 at Random State 56
# R2 Score is 0.8908608680549152 at Random State 57
# R2 Score is 0.8689286829563367 at Random State 58
# R2 Score is 0.8952109084928952 at Random State 59
# R2 Score is 0.8828817414001832 at Random State 60
# ...

# %%
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor()
parameters={'learning_rate':[0.0001,0.001,0.01,1],'base_estimator': [lr,l,knr],'n_estimators':[10,50,100,150]}
g=GridSearchCV(ada,parameters,cv=10)
g.fit(x_train,y_train)
g.best_params_
# Out:
# {'base_estimator': KNeighborsRegressor(n_neighbors=2),
#  'learning_rate': 0.01,
#  'n_estimators': 50}

# %%
ada=AdaBoostRegressor(base_estimator=knr,learning_rate=0.0001,n_estimators=150)
r_state=max_r2(ada,x,y)
# Out:
# R2 Score is 0.7646263658741069 at Random State 42
# R2 Score is 0.8463273987600779 at Random State 43
# R2 Score is 0.8478034429337743 at Random State 44
# R2 Score is 0.8352783020150055 at Random State 45
# R2 Score is 0.8497609918420961 at Random State 46
# R2 Score is 0.8098387801839568 at Random State 47
# R2 Score is 0.8839453822632964 at Random State 48
# R2 Score is 0.8793259455062401 at Random State 49
# R2 Score is 0.8751471199380074 at Random State 50
# R2 Score is 0.882702827752161 at Random State 51
# R2 Score is 0.8847466171417142 at Random State 52
# R2 Score is 0.8535288681961115 at Random State 53
# R2 Score is 0.7925788926150952 at Random State 54
# R2 Score is 0.7566224851738518 at Random State 55
# R2 Score is 0.8822355241127744 at Random State 56
# R2 Score is 0.8726884914210422 at Random State 57
# R2 Score is 0.7761408761655335 at Random State 58
# R2 Score is 0.8486836794385302 at Random State 59
# R2 Score is 0.841404969609805 at Random State 60
# ...

# %%
model=[]
cvscore=[]
MAE=[]
MSE=[]
from sklearn.model_selection import cross_val_score
MM=[lr,knr,svr,dt,l,r,ada]

for m in MM:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=100,test_size=0.20)
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('********',m,'************')
    
    mse=mean_squared_error(pred,y_test)
    print('Mean Squared Error is',mse)
    MSE.append(mse)
    
    mae=mean_absolute_error(pred,y_test)
    print('Mean Absolute Error is',mae)
    MAE.append(mae)
    
    c=cross_val_score(m,x,y,scoring='r2',cv=10).mean()
    print('CV score is',c)
    cvscore.append(c)
    print('\n')
# Out:
# ******** LinearRegression() ************
# Mean Squared Error is 0.1600430044678959
# Mean Absolute Error is 0.3152359055422683
# CV score is 0.6936030915500744
#
#
# ******** KNeighborsRegressor(n_neighbors=2) ************
# Mean Squared Error is 0.12325700842966975
# Mean Absolute Error is 0.23399493725505618
# CV score is 0.5929542227436541
#
#
# ******** SVR() ************
# Mean Squared Error is 0.08947468966249553
# Mean Absolute Error is 0.21526104123588544
# CV score is 0.7311806879333488
#
#
# ******** DecisionTreeRegressor() ************
# Mean Squared Error is 0.15515227252119418
# Mean Absolute Error is 0.26296070936488924
# CV score is 0.5530835061535007
#
#
# ******** Lasso(alpha=0.0001) ************
# Mean Squared Error is 0.160040569201936
# Mean Absolute Error is 0.3152426549432617
# CV score is 0.6936220393299883
#
#
# ******** RandomForestRegressor(n_estimators=18) ************
# Mean Squared Error is 0.07910286744863079
# ...

# %%
final=pd.DataFrame({'Model':MM,'MAE' : MAE,'MSE': MSE, 'CV SCORE':cvscore,'R2 Score' : [' 0.8190353233400884 at random state 100',
               '0.8983769568403631 at random state 69','0.9107008576743956 at random state 51','0.9035913056652797 at random state 89',
                  '0.8189493783303426 at random state 100','0.925638592707619 at random state 83','0.9009604978088566 at random state 69']})

# %%
final
# Out:
#                                                Model       MAE       MSE  \
# 0                                 LinearRegression()  0.315236  0.160043
# 1                 KNeighborsRegressor(n_neighbors=2)  0.233995  0.123257
# 2                                              SVR()  0.215261  0.089475
# 3                            DecisionTreeRegressor()  0.262961  0.155152
# 4                                Lasso(alpha=0.0001)  0.315243  0.160041
# 5  (DecisionTreeRegressor(max_features='auto', ra...  0.204688  0.079103
# 6  (KNeighborsRegressor(n_neighbors=2), KNeighbor...  0.227746  0.114198
#
#    CV SCORE                                 R2 Score
# 0  0.693603   0.8190353233400884 at random state 100
# 1  0.592954    0.8983769568403631 at random state 69
# 2  0.731181    0.9107008576743956 at random state 51
# 3  0.553084    0.9035913056652797 at random state 89
# 4  0.693622   0.8189493783303426 at random state 100
# 5  0.715401     0.925638592707619 at random state 83
# ...

# %%
#RandomForestRegressor is the best working model in the scenario

# %%
import joblib
joblib.dump(r,'concrete.obj')
# Out:
# ['concrete.obj']
